# %% [markdown]
# In this final notebook, we will use 3 different models to predict the stock price trend using previously collected and aggregated data.
# The goal is to predict the FutureTrend using price data, current trend score and sentiment scores. For this use case we will only use the FinBERT sentiment scores.
# The models we will be using are SVM, LSTM and EA-LSTM.
# EA-LSTM is an augmented version of the LSTM model that has an additional attention layer.
# More information about EA-LSTM are available [here.](https://arxiv.org/pdf/1811.03760.pdf)

# %%
import pandas as pd
import numpy as np
from math import sqrt

# %%
atvi = pd.read_csv('data/final/atvi.csv')
ntdoy = pd.read_csv('data/final/ntdoy.csv')

# %%
for col in atvi.columns:
    print(col + " " + str(sum(atvi[col].isna())))
# Out:
# Date (GMT) 0
# Last 0
# emaTrend 0
# trendBrDana 0
# fbPos 359
# fbNeg 359
# fbNeu 359
# FutureEmaTrend 10

# %%
for col in ntdoy.columns:
    print(col + " " + str(sum(ntdoy[col].isna())))
# Out:
# Date (GMT) 0
# Last 0
# emaTrend 0
# trendBrDana 0
# fbPos 8
# fbNeg 8
# fbNeu 8
# FutureEmaTrend 10

# %%
def findLastFalse(df, column, index):
    if index == 0:
        return 0
    if not pd.isna(df.loc[index - 1, column]):
        return index - 1
    return findLastFalse(df, column, index - 1)


def findNextFalse(df, column , index):
    if index == len(df[column]) - 1:
        return len(df[column]) - 1
    if not pd.isna(df.loc[index + 1, column]):
        return index + 1
    return findNextFalse(df, column, index + 1)

# %%
#we are replacing the missing sentiment values with the mean of the last available sentiment score and the first next available sentiment score
def replaceNAs(df):

    if pd.isna(df.loc[0, "fbNeg"]):
        df.loc[0, ["fbNeg", "fbPos", "fbNeu"]] = df.iloc[findNextFalse(df,"fbNeg", 0), "fbNeg"]

    if pd.isna(df.loc[df.shape[0] - 1, "fbNeg"]):
        df.loc[df.shape[0] - 1, ["fbNeg", "fbPos", "fbNeu"]] = df.iloc[findLastFalse(df,"fbNeg", df.shape[0] - 1), "fbNeg"]

    for i in range(df.shape[0]):
        if pd.isna(df.loc[i, "fbNeg"]):
            last = findLastFalse(df,"fbNeg",i)
            next = findNextFalse(df,"fbNeg",i)
            for j in [i, next - 1]:
                df.loc[j, "fbNeg"] = (df.loc[last, "fbNeg"]+df.loc[next, "fbNeg"])/2
                df.loc[j, "fbNeu"] = (df.loc[last, "fbNeu"]+df.loc[next, "fbNeu"])/2
                df.loc[j, "fbPos"] = (df.loc[last, "fbPos"]+df.loc[next, "fbPos"])/2
            i = next

# %%
replaceNAs(atvi)
replaceNAs(ntdoy)

atvi.FutureEmaTrend.fillna(0,inplace=True)
ntdoy.FutureEmaTrend.fillna(0, inplace=True)

# %%
#checking if there are any missing values left
for col in atvi.columns:
    print(col + " " + str(sum(atvi[col].isna())))
print()
for col in ntdoy.columns:
    print(col + " " + str(sum(ntdoy[col].isna())))
# Out:
# Date (GMT) 0
# Last 0
# emaTrend 0
# trendBrDana 0
# fbPos 0
# fbNeg 0
# fbNeu 0
# FutureEmaTrend 0
#
# Date (GMT) 0
# Last 0
# emaTrend 0
# trendBrDana 0
# fbPos 0
# fbNeg 0
# fbNeu 0
# FutureEmaTrend 0

# %% [markdown]
# Because of some problems with tweet scraping, ATVI had more missing values and therefore we will be using NTDOY

# %%
data = ntdoy.copy()

# %%
data.Last = (data.Last-data.Last.min())/(data.Last.max()-data.Last.min()) #normalization

# %%
#SVM does not allow tensors for input so we will manually add shifted collumns
def pomereneKolone(data, columns_to_shift, num_shifts):

    df = data.copy()

    last_column_index = df.columns.get_loc(df.columns[-1])

    for column in columns_to_shift:
        for i in range(1, num_shifts + 1):
            shifted_column_name = f'{column}_shifted_{i}'
            df[shifted_column_name] = df[column].shift(i)

    df.dropna(inplace=True)

    #moving the output column to the last space
    column_to_move = df.columns[last_column_index]
    other_columns = [col for col in df.columns if col != column_to_move]
    df = df[other_columns + [column_to_move]]

    return df

# %%
data_svm = pomereneKolone(data,["Last","emaTrend"],5)

# %%
#added normalization for LSTM
data.emaTrend = (data.emaTrend + 1)/2
data.trendBrDana = (data.trendBrDana + 1)/2
data.FutureEmaTrend = data.FutureEmaTrend + 1

# %%
data_svm.head()
# Out:
#    Date (GMT)      Last  emaTrend  trendBrDana     fbPos     fbNeg     fbNeu  \
# 5  2019-01-09  0.058337         1            0  0.056432  0.026387  0.917181
# 6  2019-01-10  0.046023         1            0  0.288594  0.163498  0.547908
# 7  2019-01-11  0.044913         1            0  0.073317  0.022390  0.904293
# 8  2019-01-14  0.058740         1            0  0.141267  0.065509  0.793224
# 9  2019-01-15  0.082862         1            0  0.148546  0.031439  0.820014
#
#    Last_shifted_1  Last_shifted_2  Last_shifted_3  Last_shifted_4  \
# 5        0.043096        0.036334        0.020993        0.012919
# 6        0.058337        0.043096        0.036334        0.020993
# 7        0.046023        0.058337        0.043096        0.036334
# 8        0.044913        0.046023        0.058337        0.043096
# 9        0.058740        0.044913        0.046023        0.058337
#
#    Last_shifted_5  emaTrend_shifted_1  emaTrend_shifted_2  emaTrend_shifted_3  \
# 5        0.018571                 1.0                 1.0                 1.0
# 6        0.012919                 1.0                 1.0                 1.0
# 7        0.020993                 1.0                 1.0                 1.0
# 8        0.036334                 1.0                 1.0                 1.0
# 9        0.043096                 1.0                 1.0                 1.0
#
#    emaTrend_shifted_4  emaTrend_shifted_5  FutureEmaTrend
# 5                -1.0                 0.0             1.0
# 6                 1.0                -1.0             1.0
# 7                 1.0                 1.0            -1.0
# 8                 1.0                 1.0             1.0
# 9                 1.0                 1.0             1.0

# %%
#Now we are splitting the data nad removing the Date column
def podela(df):
    #podela podataka
    train = df.loc[df["Date (GMT)"] < "2022-01-01"]
    test = df.loc[df["Date (GMT)"] > "2021-12-31"]

    #izbacivanje kolone datum
    train = train.iloc[:,1:]
    test = test.iloc[:,1:]

    X_train = train.iloc[:, :-1]
    X_test = test.iloc[:, :-1]
    y_train = train.iloc[:, -1]
    y_test = test.iloc[:, -1]



    return X_train,X_test,y_train,y_test

# %%
X_train,X_test,y_train,y_test = podela(data)
X_trainsvm,X_testsvm,y_trainsvm,y_testsvm = podela(data_svm)

# %% [markdown]
# <b>SVM</b>

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
model_svc = SVC(kernel='rbf',gamma=0.5, C=10)

# %%
model_svc.fit(X_trainsvm,y_trainsvm)
# Out:
# SVC(C=10, gamma=0.5)

# %%
predictions = model_svc.predict(X_testsvm)

# %%
accuracy_score(y_testsvm, predictions)
# Out:
# 0.5059760956175299

# %% [markdown]
# Testing different hyperparameters

# %%
parameters = {
    'C':[2500, 2000, 1800, 1500, 1000, 100, 10, 1],
    'gamma': ['scale', 'auto', 1, 0.5, 0.2],
    'kernel':['linear', 'poly', 'rbf', 'sigmoid']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
cv = [(slice(None), slice(None))] #to use GridSearch without cross-validation because we are working with a time series

# %%
gs = GridSearchCV(estimator=model_svc, param_grid=parameters,
                   cv=cv, n_jobs=-1)

# %%
gs.fit(data_svm.iloc[:,1:12],data_svm.iloc[:,12])
# Out:
# GridSearchCV(cv=[(slice(None, None, None), slice(None, None, None))],
#              estimator=SVC(C=10, gamma=0.5), n_jobs=-1,
#              param_grid={'C': [2500, 2000, 1800, 1500, 1000, 100, 10, 1],
#                          'gamma': ['scale', 'auto', 1, 0.5, 0.2],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
print(f"Best params: C:" + str(gs.best_estimator_.C) + ", gamma:" + str(gs.best_estimator_.gamma) + " kernel:" + str(gs.best_estimator_.kernel))
# Out:
# Best params: C:2500, gamma:1 kernel:rbf

# %% [markdown]
# New model with optimal hyperparameters

# %%
model_svc = SVC(kernel='rbf',gamma=1, C=2500)
model_svc.fit(X_trainsvm,y_trainsvm)
predictions = model_svc.predict(X_testsvm)

# %%
accuracy_score(y_testsvm, predictions)
# Out:
# 0.5338645418326693

# %% [markdown]
# <b>LSTM</b>

# %%
#pip install tensorflow
import tensorflow as tf
from keras.models import Sequential
from keras.layers import *
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.models import load_model, save_model
from sklearn.metrics import mean_squared_error, accuracy_score

# %% [markdown]
# Adding time-steps

# %%
time_steps = 7
num_classes = 3

prepend_features = X_train.iloc[-(time_steps-1):]
X_test2 = pd.concat([prepend_features, X_test], axis=0)

X_train1, y_train1 = [], []
for i in range(y_train.shape[0] - (time_steps-1)):
    X_train1.append(X_train.iloc[i:i+time_steps].values)
    y_train1.append(y_train.iloc[i + (time_steps-1)])
X_train1, y_train1 = np.array(X_train1), np.array(y_train1).reshape(-1, 1)
print(f'Train data dimensions: {X_train1.shape}, {y_train1.shape}')

X_test1, y_test1 = [], []
for i in range(y_test.shape[0]):
    X_test1.append(X_test2.iloc[i:i+time_steps].values)
    y_test1.append(y_test.iloc[i])
X_test1, y_test1 = np.array(X_test1), np.array(y_test1).reshape(-1, 1)

print(f'Test data dimensions: {X_test1.shape}, {y_test1.shape}')

y_testcat = to_categorical(y_test1, num_classes=3)
y_traincat = to_categorical(y_train1, num_classes=3)
# Out:
# Train data dimensions: (751, 7, 6), (751, 1)
# Test data dimensions: (251, 7, 6), (251, 1)

# %% [markdown]
# Creating initial model

# %%
model = Sequential()
model.add(InputLayer((7,X_train1.shape[2])))
model.add(LSTM(256, return_sequences=True))
model.add(LSTM(128))
model.add(Dense(3,"softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 256)            269312
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 3)                 387
#
# =================================================================
# Total params: 466,819
# Trainable params: 466,819
# Non-trainable params: 0
# _________________________________________________________________

# %%
#saving the model from the best training epoch
cp = ModelCheckpoint('models/lstm/', save_best_only=True, monitor='val_accuracy')

# %%
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0007), metrics=['accuracy'])

# %%
# from keras.callbacks import ReduceLROnPlateau
# reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.9, patience=5, verbose=1)

# %%
#training the network
model.fit(X_train1,y_traincat,validation_data=(X_test1,y_testcat),epochs=50,callbacks=[cp])#reduce_lr
# Out:
# Epoch 1/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.7771 - accuracy: 0.4864
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 20s 627ms/step - loss: 0.7760 - accuracy: 0.4847 - val_loss: 1.0937 - val_accuracy: 0.4343
# Epoch 2/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6952 - accuracy: 0.5380
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 12s 523ms/step - loss: 0.6949 - accuracy: 0.5393 - val_loss: 1.0481 - val_accuracy: 0.4980
# Epoch 3/50
# 24/24 [==============================] - 1s 63ms/step - loss: 0.6804 - accuracy: 0.5526 - val_loss: 1.0157 - val_accuracy: 0.4741
# Epoch 4/50
# 24/24 [==============================] - 1s 61ms/step - loss: 0.6808 - accuracy: 0.5632 - val_loss: 1.0024 - val_accuracy: 0.4701
# Epoch 5/50
# 24/24 [==============================] - 2s 66ms/step - loss: 0.6776 - accuracy: 0.5806 - val_loss: 1.0083 - val_accuracy: 0.4781
# Epoch 6/50
# 24/24 [==============================] - 2s 68ms/step - loss: 0.6758 - accuracy: 0.5659 - val_loss: 1.0259 - val_accuracy: 0.4502
# Epoch 7/50
# 24/24 [==============================] - 1s 57ms/step - loss: 0.7091 - accuracy: 0.5539 - val_loss: 0.9034 - val_accuracy: 0.4343
# Epoch 8/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6846 - accuracy: 0.5639
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 12s 525ms/step - loss: 0.6847 - accuracy: 0.5619 - val_loss: 0.9541 - val_accuracy: 0.5219
# Epoch 9/50
# 24/24 [==============================] - 2s 72ms/step - loss: 0.6786 - accuracy: 0.5806 - val_loss: 0.9896 - val_accuracy: 0.5060
# Epoch 10/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6729 - accuracy: 0.5788
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 12s 522ms/step - loss: 0.6730 - accuracy: 0.5779 - val_loss: 0.9969 - val_accuracy: 0.5299
# Epoch 11/50
# 24/24 [==============================] - 2s 81ms/step - loss: 0.6764 - accuracy: 0.5832 - val_loss: 0.9858 - val_accuracy: 0.5020
# Epoch 12/50
# 24/24 [==============================] - 2s 74ms/step - loss: 0.6730 - accuracy: 0.5899 - val_loss: 0.9927 - val_accuracy: 0.5259
# Epoch 13/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6826 - accuracy: 0.5598
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 14s 612ms/step - loss: 0.6823 - accuracy: 0.5619 - val_loss: 0.9390 - val_accuracy: 0.5498
# Epoch 14/50
# 24/24 [==============================] - 2s 65ms/step - loss: 0.6773 - accuracy: 0.5659 - val_loss: 1.0057 - val_accuracy: 0.4582
# Epoch 15/50
# 24/24 [==============================] - 2s 74ms/step - loss: 0.6787 - accuracy: 0.5832 - val_loss: 0.9605 - val_accuracy: 0.4940
# Epoch 16/50
# 24/24 [==============================] - 2s 82ms/step - loss: 0.6715 - accuracy: 0.5965 - val_loss: 0.9908 - val_accuracy: 0.5139
# Epoch 17/50
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6723 - accuracy: 0.5779 - val_loss: 0.9957 - val_accuracy: 0.4781
# Epoch 18/50
# 24/24 [==============================] - 2s 72ms/step - loss: 0.6785 - accuracy: 0.5699 - val_loss: 0.9930 - val_accuracy: 0.4303
# Epoch 19/50
# 24/24 [==============================] - ETA: 0s - loss: 0.6700 - accuracy: 0.5899
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 13s 544ms/step - loss: 0.6700 - accuracy: 0.5899 - val_loss: 0.9779 - val_accuracy: 0.5578
# Epoch 20/50
# 24/24 [==============================] - 2s 95ms/step - loss: 0.6691 - accuracy: 0.5859 - val_loss: 0.9989 - val_accuracy: 0.4980
# Epoch 21/50
# 24/24 [==============================] - 2s 73ms/step - loss: 0.6682 - accuracy: 0.5712 - val_loss: 0.9864 - val_accuracy: 0.5100
# Epoch 22/50
# 24/24 [==============================] - 2s 71ms/step - loss: 0.6684 - accuracy: 0.5752 - val_loss: 1.0039 - val_accuracy: 0.5060
# Epoch 23/50
# 24/24 [==============================] - 2s 71ms/step - loss: 0.6656 - accuracy: 0.5952 - val_loss: 1.0315 - val_accuracy: 0.5020
# Epoch 24/50
# 24/24 [==============================] - 2s 83ms/step - loss: 0.6789 - accuracy: 0.5486 - val_loss: 0.9559 - val_accuracy: 0.5418
# Epoch 25/50
# 24/24 [==============================] - 2s 85ms/step - loss: 0.6728 - accuracy: 0.5819 - val_loss: 0.9683 - val_accuracy: 0.5538
# Epoch 26/50
# 24/24 [==============================] - 2s 85ms/step - loss: 0.6717 - accuracy: 0.5872 - val_loss: 0.9793 - val_accuracy: 0.5179
# Epoch 27/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6658 - accuracy: 0.6005
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 12s 538ms/step - loss: 0.6680 - accuracy: 0.5979 - val_loss: 0.9639 - val_accuracy: 0.5657
# Epoch 28/50
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6631 - accuracy: 0.5965 - val_loss: 0.9684 - val_accuracy: 0.5538
# Epoch 29/50
# 24/24 [==============================] - 2s 75ms/step - loss: 0.6672 - accuracy: 0.5792 - val_loss: 0.9783 - val_accuracy: 0.4821
# Epoch 30/50
# 24/24 [==============================] - 2s 69ms/step - loss: 0.6640 - accuracy: 0.5912 - val_loss: 0.9643 - val_accuracy: 0.5498
# Epoch 31/50
# 24/24 [==============================] - 2s 74ms/step - loss: 0.6658 - accuracy: 0.5925 - val_loss: 0.9671 - val_accuracy: 0.5179
# Epoch 32/50
# 24/24 [==============================] - 2s 82ms/step - loss: 0.6622 - accuracy: 0.5846 - val_loss: 0.9837 - val_accuracy: 0.5299
# Epoch 33/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6603 - accuracy: 0.6005
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 15s 640ms/step - loss: 0.6594 - accuracy: 0.6019 - val_loss: 0.9723 - val_accuracy: 0.5777
# Epoch 34/50
# 24/24 [==============================] - 2s 65ms/step - loss: 0.6652 - accuracy: 0.5952 - val_loss: 0.9663 - val_accuracy: 0.5777
# Epoch 35/50
# 24/24 [==============================] - 1s 59ms/step - loss: 0.6635 - accuracy: 0.5979 - val_loss: 0.9809 - val_accuracy: 0.5020
# Epoch 36/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6629 - accuracy: 0.6005
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 15s 646ms/step - loss: 0.6632 - accuracy: 0.5992 - val_loss: 0.9665 - val_accuracy: 0.5817
# Epoch 37/50
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6587 - accuracy: 0.5885 - val_loss: 0.9869 - val_accuracy: 0.5378
# Epoch 38/50
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6585 - accuracy: 0.5939 - val_loss: 0.9989 - val_accuracy: 0.5538
# Epoch 39/50
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6667 - accuracy: 0.5806 - val_loss: 0.9856 - val_accuracy: 0.5578
# Epoch 40/50
# 24/24 [==============================] - 2s 82ms/step - loss: 0.6536 - accuracy: 0.5952 - val_loss: 1.0241 - val_accuracy: 0.5538
# Epoch 41/50
# 24/24 [==============================] - 2s 86ms/step - loss: 0.6537 - accuracy: 0.5992 - val_loss: 0.9794 - val_accuracy: 0.5737
# Epoch 42/50
# 24/24 [==============================] - 2s 72ms/step - loss: 0.6616 - accuracy: 0.5899 - val_loss: 0.9821 - val_accuracy: 0.5777
# Epoch 43/50
# 24/24 [==============================] - 2s 73ms/step - loss: 0.6514 - accuracy: 0.6059 - val_loss: 0.9894 - val_accuracy: 0.5339
# Epoch 44/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6485 - accuracy: 0.6141
# WARNING:absl:Found untraced functions such as lstm_cell_70_layer_call_fn, lstm_cell_70_layer_call_and_return_conditional_losses, lstm_cell_71_layer_call_fn, lstm_cell_71_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model5c\assets
# INFO:tensorflow:Assets written to: model5c\assets
# 24/24 [==============================] - 13s 572ms/step - loss: 0.6495 - accuracy: 0.6125 - val_loss: 1.0120 - val_accuracy: 0.5936
# Epoch 45/50
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6515 - accuracy: 0.5912 - val_loss: 0.9702 - val_accuracy: 0.5777
# Epoch 46/50
# 24/24 [==============================] - 2s 98ms/step - loss: 0.6471 - accuracy: 0.6059 - val_loss: 1.0165 - val_accuracy: 0.5538
# Epoch 47/50
# 24/24 [==============================] - 2s 74ms/step - loss: 0.6411 - accuracy: 0.6125 - val_loss: 1.0634 - val_accuracy: 0.5458
# Epoch 48/50
# 24/24 [==============================] - 2s 70ms/step - loss: 0.6495 - accuracy: 0.6072 - val_loss: 1.0431 - val_accuracy: 0.5538
# Epoch 49/50
# 24/24 [==============================] - 1s 60ms/step - loss: 0.6459 - accuracy: 0.6165 - val_loss: 1.0197 - val_accuracy: 0.5299
# Epoch 50/50
# 24/24 [==============================] - 2s 63ms/step - loss: 0.6412 - accuracy: 0.6059 - val_loss: 1.0116 - val_accuracy: 0.5179

# %%
#Checking the best learning rate
# lrs = [0.004,0.003,0.002,0.0018,0.0013,0.0011,0.0010,0.0009,0.0008,0.0007,0.0006,0.0005,0.0004,0.0003,0.0002]
#
# for lr in lrs:
#     model = Sequential()
#     model.add(InputLayer((11,1)))
#     model.add(LSTM(128, return_sequences=True))
#     model.add(LSTM(128))
#     model.add(Dense(8,"relu"))
#     model.add(Dense(3,"softmax"))
#
#     model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=lr), metrics=['accuracy'])
#     model.fit(X_train,(y_train+1),validation_data=(X_test,(y_test + 1)),epochs=20,callbacks=[cp])

# %%
#loading the best epoch model
model = load_model('models/lstm/')

# %%
lstm_predictions = model.predict(X_test1)
# Out:
# 8/8 [==============================] - 3s 26ms/step

# %%
lstm_predictions[0:5]
# Out:
# array([[5.8446944e-01, 8.9780529e-05, 4.1544074e-01],
#        [5.5865902e-01, 1.1288827e-04, 4.4122815e-01],
#        [6.3111371e-01, 1.7095068e-04, 3.6871538e-01],
#        [7.2440594e-01, 3.0656825e-04, 2.7528745e-01],
#        [6.5444452e-01, 3.8827819e-04, 3.4516716e-01]], dtype=float32)

# %%
predicted_classes = np.argmax(lstm_predictions, axis=1)

# %%
accuracy_score(y_test1,predicted_classes)
# Out:
# 0.5936254980079682

# %% [markdown]
# <b>EA-LSTM</b>

# %%
from ea_lstm import (initialize_weights, individual_to_key,pop_to_weights,
                     select, reconstruct_population,apply_weight, is_minimum, is_maximum)
from sklearn.metrics import mean_absolute_error
from math import sqrt
from copy import copy
from keras.callbacks import EarlyStopping, LambdaCallback
import json

# %%
#Creating initial model
def make_model():
    model = Sequential()
    model.add(InputLayer((7,6)))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(128))
    model.add(Dense(3,"softmax"))

    return model

# %%
best_model = make_model()
best_weight = [1.0] * time_steps

# %%
best_model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0007), metrics=['accuracy'])
cpea = ModelCheckpoint('models/lstm_temp/', save_best_only=True, monitor='val_accuracy')

# %%
#Initial training

best_model.fit(apply_weight(X_train1, best_weight), y_traincat, epochs=35,
               validation_data=(apply_weight(X_test1, best_weight), y_testcat), callbacks=[cpea])
# Out:
# Epoch 1/35
# 24/24 [==============================] - ETA: 0s - loss: 0.8109 - accuracy: 0.5193
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelealstm\assets
# INFO:tensorflow:Assets written to: modelealstm\assets
# 24/24 [==============================] - 18s 521ms/step - loss: 0.8109 - accuracy: 0.5193 - val_loss: 0.9576 - val_accuracy: 0.5259
# Epoch 2/35
# 24/24 [==============================] - 1s 22ms/step - loss: 0.6955 - accuracy: 0.5340 - val_loss: 0.9971 - val_accuracy: 0.5259
# Epoch 3/35
# 24/24 [==============================] - 1s 24ms/step - loss: 0.6865 - accuracy: 0.5459 - val_loss: 0.9644 - val_accuracy: 0.4861
# Epoch 4/35
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6974 - accuracy: 0.5406 - val_loss: 0.9428 - val_accuracy: 0.4900
# Epoch 5/35
# 24/24 [==============================] - 1s 23ms/step - loss: 0.6928 - accuracy: 0.5286 - val_loss: 0.9220 - val_accuracy: 0.4622
# Epoch 6/35
# 24/24 [==============================] - 1s 24ms/step - loss: 0.6831 - accuracy: 0.5686 - val_loss: 0.9359 - val_accuracy: 0.4821
# Epoch 7/35
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6786 - accuracy: 0.5832 - val_loss: 0.9549 - val_accuracy: 0.5259
# Epoch 8/35
# 24/24 [==============================] - 1s 32ms/step - loss: 0.6781 - accuracy: 0.5686 - val_loss: 1.0067 - val_accuracy: 0.4343
# Epoch 9/35
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6916 - accuracy: 0.5553 - val_loss: 0.9176 - val_accuracy: 0.4701
# Epoch 10/35
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6809 - accuracy: 0.5752 - val_loss: 0.9320 - val_accuracy: 0.5139
# Epoch 11/35
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6775 - accuracy: 0.5739 - val_loss: 0.9546 - val_accuracy: 0.5100
# Epoch 12/35
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6792 - accuracy: 0.5579 - val_loss: 0.9545 - val_accuracy: 0.5139
# Epoch 13/35
# 24/24 [==============================] - 1s 27ms/step - loss: 0.6760 - accuracy: 0.5699 - val_loss: 0.9577 - val_accuracy: 0.5139
# Epoch 14/35
# 24/24 [==============================] - 1s 29ms/step - loss: 0.6713 - accuracy: 0.5832 - val_loss: 0.9743 - val_accuracy: 0.5219
# Epoch 15/35
# 24/24 [==============================] - 1s 29ms/step - loss: 0.6739 - accuracy: 0.5779 - val_loss: 0.9704 - val_accuracy: 0.5139
# Epoch 16/35
# 24/24 [==============================] - 1s 26ms/step - loss: 0.6697 - accuracy: 0.5939 - val_loss: 1.0041 - val_accuracy: 0.4622
# Epoch 17/35
# 24/24 [==============================] - 1s 28ms/step - loss: 0.6829 - accuracy: 0.5646 - val_loss: 0.9720 - val_accuracy: 0.4462
# Epoch 18/35
# 24/24 [==============================] - 1s 27ms/step - loss: 0.6727 - accuracy: 0.5779 - val_loss: 0.9404 - val_accuracy: 0.5259
# Epoch 19/35
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6816 - accuracy: 0.5788
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelealstm\assets
# INFO:tensorflow:Assets written to: modelealstm\assets
# 24/24 [==============================] - 13s 581ms/step - loss: 0.6814 - accuracy: 0.5779 - val_loss: 0.9272 - val_accuracy: 0.5458
# Epoch 20/35
# 24/24 [==============================] - 1s 31ms/step - loss: 0.6684 - accuracy: 0.5806 - val_loss: 0.9555 - val_accuracy: 0.5339
# Epoch 21/35
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6794 - accuracy: 0.5473 - val_loss: 0.9370 - val_accuracy: 0.5299
# Epoch 22/35
# 24/24 [==============================] - ETA: 0s - loss: 0.6680 - accuracy: 0.6059
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelealstm\assets
# INFO:tensorflow:Assets written to: modelealstm\assets
# 24/24 [==============================] - 12s 521ms/step - loss: 0.6680 - accuracy: 0.6059 - val_loss: 0.9721 - val_accuracy: 0.5737
# Epoch 23/35
# 24/24 [==============================] - 1s 36ms/step - loss: 0.6646 - accuracy: 0.5846 - val_loss: 0.9844 - val_accuracy: 0.5339
# Epoch 24/35
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6649 - accuracy: 0.5912 - val_loss: 0.9831 - val_accuracy: 0.5259
# Epoch 25/35
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6651 - accuracy: 0.5832 - val_loss: 0.9850 - val_accuracy: 0.5578
# Epoch 26/35
# 24/24 [==============================] - 1s 36ms/step - loss: 0.6635 - accuracy: 0.5792 - val_loss: 0.9972 - val_accuracy: 0.5737
# Epoch 27/35
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6735 - accuracy: 0.5553 - val_loss: 0.9341 - val_accuracy: 0.5179
# Epoch 28/35
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6716 - accuracy: 0.5766 - val_loss: 0.9508 - val_accuracy: 0.5299
# Epoch 29/35
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6631 - accuracy: 0.5912 - val_loss: 0.9856 - val_accuracy: 0.5538
# Epoch 30/35
# 22/24 [==========================>...] - ETA: 0s - loss: 0.6576 - accuracy: 0.6051
# WARNING:absl:Found untraced functions such as lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_9_layer_call_fn, lstm_cell_9_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: modelealstm\assets
# INFO:tensorflow:Assets written to: modelealstm\assets
# 24/24 [==============================] - 12s 507ms/step - loss: 0.6598 - accuracy: 0.6005 - val_loss: 1.0032 - val_accuracy: 0.5857
# Epoch 31/35
# 24/24 [==============================] - 1s 30ms/step - loss: 0.6597 - accuracy: 0.5872 - val_loss: 1.0379 - val_accuracy: 0.4622
# Epoch 32/35
# 24/24 [==============================] - 1s 30ms/step - loss: 0.6657 - accuracy: 0.5846 - val_loss: 0.9359 - val_accuracy: 0.5139
# Epoch 33/35
# 24/24 [==============================] - 1s 27ms/step - loss: 0.6685 - accuracy: 0.5779 - val_loss: 0.9472 - val_accuracy: 0.5737
# Epoch 34/35
# 24/24 [==============================] - 1s 28ms/step - loss: 0.6589 - accuracy: 0.6005 - val_loss: 1.0245 - val_accuracy: 0.5378
# Epoch 35/35
# 24/24 [==============================] - 1s 28ms/step - loss: 0.6574 - accuracy: 0.5912 - val_loss: 1.0228 - val_accuracy: 0.5458

# %%
best_model = load_model('models/lstm_temp/')

# %%
#Defining LambdaCallback-a so we can save the best epoch model in each loop iteration without creating new save files
def save_best_epoch_model(epoch, logs):
    global best_val_accuracy, best_model_weights
    val_accuracy = logs.get('val_accuracy')
    if val_accuracy > best_val_accuracy:
        best_val_accuracy = val_accuracy
        best_model_weights = model.get_weights()

save_best_model = LambdaCallback(on_epoch_end=lambda epoch, logs: save_best_epoch_model(epoch, logs))

# %%
#to reduce overfitting we are adding an earlystopper to end the training if val_acc doesnt improve for 10 epochs
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, verbose=1, restore_best_weights=True)

# %%
#competitive random search
pop_size = 36
code_length = 6
iterations = 20
n_select = 6
time_steps = 7

pop, weights = initialize_weights(pop_size, time_steps, code_length)
key_to_rmse = {}

for iteration in range(iterations):
    for enum, (indiv, weight) in enumerate(zip(pop, weights)):
        print('iteration: [%d/%d] indiv_no: [%d/%d]' % (iteration + 1, iterations, enum + 1, pop_size))
        key = individual_to_key(indiv)
        if key not in key_to_rmse.keys():

            best_val_accuracy = 0.0
            best_model_weights = None

            model = make_model()
            model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0007), metrics=['accuracy'])
            model.set_weights(best_model.get_weights())
            model.fit(apply_weight(X_train1, weight), y_traincat, epochs=20,
                      validation_data=(apply_weight(X_test1, weight), y_testcat), callbacks=[early_stop, save_best_model])

            model.set_weights(best_model_weights)

            pred_y = model.predict(apply_weight(X_test1, weight))
            inv_pred_y = np.argmax(pred_y, axis=1)
            inv_valid_y = y_test1
            val_loss, acc = model.evaluate(apply_weight(X_test1, weight), y_testcat)
            rmse = sqrt(mean_squared_error(inv_valid_y, inv_pred_y))
            mae = mean_absolute_error(inv_valid_y, inv_pred_y)
            print("RMSE: %.4f, MAE: %.4f, ACC: %.4f, VAL_LOSS: %.4f" % (rmse, mae, acc, val_loss))
            #algoritam je napravljen za minimiziranje rmse, pa ako koristimo accuracy moramo da ga promenimo
            negacc = 1 - acc
            if is_minimum(negacc, key_to_rmse):
                best_model.set_weights(model.get_weights())
                best_weight = copy(weight)
            key_to_rmse[key] = negacc

    pop_selected, fitness_selected = select(pop, n_select, key_to_rmse)
    pop = reconstruct_population(pop_selected, pop_size)
    weights = pop_to_weights(pop, time_steps, code_length)
# Out:
# iteration: [1/20] indiv_no: [1/36]
# Epoch 1/20
# 24/24 [==============================] - 11s 131ms/step - loss: 0.6542 - accuracy: 0.6178 - val_loss: 1.0273 - val_accuracy: 0.5299
# Epoch 2/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6480 - accuracy: 0.6045 - val_loss: 1.1714 - val_accuracy: 0.5498
# Epoch 3/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6476 - accuracy: 0.5912 - val_loss: 1.1338 - val_accuracy: 0.5299
# Epoch 4/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6475 - accuracy: 0.6099 - val_loss: 1.1273 - val_accuracy: 0.4861
# Epoch 5/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6431 - accuracy: 0.6045 - val_loss: 1.1394 - val_accuracy: 0.5299
# Epoch 6/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6455 - accuracy: 0.6005 - val_loss: 1.1442 - val_accuracy: 0.5418
# Epoch 7/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6404 - accuracy: 0.6285 - val_loss: 1.2246 - val_accuracy: 0.5458
# Epoch 8/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6450 - accuracy: 0.6152 - val_loss: 1.1055 - val_accuracy: 0.4940
# Epoch 9/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.6377 - accuracy: 0.6458 - val_loss: 1.1968 - val_accuracy: 0.5618
# Epoch 10/20
# 24/24 [==============================] - 1s 34ms/step - loss: 0.6516 - accuracy: 0.5952 - val_loss: 1.0405 - val_accuracy: 0.4661
# Epoch 11/20
# 24/24 [==============================] - 1s 35ms/step - loss: 0.6468 - accuracy: 0.6352 - val_loss: 1.1118 - val_accuracy: 0.5498
# Epoch 12/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6477 - accuracy: 0.6258 - val_loss: 1.0938 - val_accuracy: 0.5139
# Epoch 13/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6450 - accuracy: 0.6245 - val_loss: 1.0919 - val_accuracy: 0.5538
# Epoch 14/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6408 - accuracy: 0.6099 - val_loss: 1.1382 - val_accuracy: 0.5378
# Epoch 15/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6383 - accuracy: 0.6152 - val_loss: 1.1936 - val_accuracy: 0.4622
# Epoch 16/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6439 - accuracy: 0.6205 - val_loss: 1.1536 - val_accuracy: 0.4940
# Epoch 17/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6397 - accuracy: 0.6352 - val_loss: 1.1188 - val_accuracy: 0.5538
# Epoch 18/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6464 - accuracy: 0.6178 - val_loss: 1.1033 - val_accuracy: 0.5219
# Epoch 19/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6364 - accuracy: 0.6391Restoring model weights from the end of the best epoch: 9.
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6364 - accuracy: 0.6391 - val_loss: 1.1723 - val_accuracy: 0.5458
# Epoch 19: early stopping
# 8/8 [==============================] - 2s 19ms/step
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1968 - accuracy: 0.5618
# RMSE: 1.2781, MAE: 0.8367, ACC: 0.5618, VAL_LOSS: 1.1968
# iteration: [1/20] indiv_no: [2/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 81ms/step - loss: 0.6582 - accuracy: 0.6005 - val_loss: 1.0884 - val_accuracy: 0.5657
# Epoch 2/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.6531 - accuracy: 0.6245 - val_loss: 0.9850 - val_accuracy: 0.5378
# Epoch 3/20
# 24/24 [==============================] - 1s 32ms/step - loss: 0.6400 - accuracy: 0.6152 - val_loss: 1.1379 - val_accuracy: 0.5378
# Epoch 4/20
# 24/24 [==============================] - 1s 33ms/step - loss: 0.6424 - accuracy: 0.6245 - val_loss: 1.1123 - val_accuracy: 0.4781
# Epoch 5/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.6381 - accuracy: 0.6232 - val_loss: 1.1202 - val_accuracy: 0.5498
# Epoch 6/20
# 24/24 [==============================] - 1s 31ms/step - loss: 0.6311 - accuracy: 0.6245 - val_loss: 1.1994 - val_accuracy: 0.5060
# Epoch 7/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6467 - accuracy: 0.6258 - val_loss: 1.0789 - val_accuracy: 0.5458
# Epoch 8/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6346 - accuracy: 0.6365 - val_loss: 1.1370 - val_accuracy: 0.5139
# Epoch 9/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6347 - accuracy: 0.6511 - val_loss: 1.1059 - val_accuracy: 0.5100
# Epoch 10/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6343 - accuracy: 0.6298 - val_loss: 1.1710 - val_accuracy: 0.5418
# Epoch 11/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6354 - accuracy: 0.6196Restoring model weights from the end of the best epoch: 1.
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6352 - accuracy: 0.6192 - val_loss: 1.1460 - val_accuracy: 0.4741
# Epoch 11: early stopping
# 8/8 [==============================] - 1s 18ms/step
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0884 - accuracy: 0.5657
# RMSE: 1.2718, MAE: 0.8287, ACC: 0.5657, VAL_LOSS: 1.0884
# iteration: [1/20] indiv_no: [3/36]
# Epoch 1/20
# 24/24 [==============================] - 27s 208ms/step - loss: 0.6817 - accuracy: 0.5619 - val_loss: 0.9569 - val_accuracy: 0.4422
# Epoch 2/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6452 - accuracy: 0.6178 - val_loss: 0.9687 - val_accuracy: 0.5657
# Epoch 3/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6392 - accuracy: 0.6165 - val_loss: 1.0842 - val_accuracy: 0.4821
# Epoch 4/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6449 - accuracy: 0.6005 - val_loss: 1.0669 - val_accuracy: 0.5299
# Epoch 5/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6458 - accuracy: 0.6112 - val_loss: 1.0741 - val_accuracy: 0.4940
# Epoch 6/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6378 - accuracy: 0.6245 - val_loss: 1.0787 - val_accuracy: 0.5179
# Epoch 7/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6354 - accuracy: 0.6125 - val_loss: 1.0808 - val_accuracy: 0.5100
# Epoch 8/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6332 - accuracy: 0.5992 - val_loss: 1.0906 - val_accuracy: 0.5259
# Epoch 9/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.6383 - accuracy: 0.6059 - val_loss: 1.1017 - val_accuracy: 0.5259
# Epoch 10/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6332 - accuracy: 0.6152 - val_loss: 1.0863 - val_accuracy: 0.4741
# Epoch 11/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6452 - accuracy: 0.6138 - val_loss: 1.0625 - val_accuracy: 0.5538
# Epoch 12/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6342 - accuracy: 0.6005Restoring model weights from the end of the best epoch: 2.
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6333 - accuracy: 0.6019 - val_loss: 1.0461 - val_accuracy: 0.5060
# Epoch 12: early stopping
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 16ms/step - loss: 0.9687 - accuracy: 0.5657
# RMSE: 1.2718, MAE: 0.8287, ACC: 0.5657, VAL_LOSS: 0.9687
# iteration: [1/20] indiv_no: [4/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 109ms/step - loss: 0.6646 - accuracy: 0.5752 - val_loss: 1.0120 - val_accuracy: 0.5378
# Epoch 2/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6522 - accuracy: 0.6072 - val_loss: 1.0880 - val_accuracy: 0.5339
# Epoch 3/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6462 - accuracy: 0.6099 - val_loss: 1.1594 - val_accuracy: 0.5578
# Epoch 4/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.6496 - accuracy: 0.6165 - val_loss: 1.1530 - val_accuracy: 0.5777
# Epoch 5/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6521 - accuracy: 0.6045 - val_loss: 1.0554 - val_accuracy: 0.4661
# Epoch 6/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6464 - accuracy: 0.6125 - val_loss: 1.1725 - val_accuracy: 0.5538
# Epoch 7/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6458 - accuracy: 0.6032 - val_loss: 1.2039 - val_accuracy: 0.5697
# Epoch 8/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6450 - accuracy: 0.6099 - val_loss: 1.1021 - val_accuracy: 0.4382
# Epoch 9/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6466 - accuracy: 0.6152 - val_loss: 1.0716 - val_accuracy: 0.5458
# Epoch 10/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6432 - accuracy: 0.6032 - val_loss: 1.1797 - val_accuracy: 0.4701
# Epoch 11/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6410 - accuracy: 0.6205 - val_loss: 1.1898 - val_accuracy: 0.5697
# Epoch 12/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6408 - accuracy: 0.6059 - val_loss: 1.1468 - val_accuracy: 0.4622
# Epoch 13/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6406 - accuracy: 0.6072 - val_loss: 1.1986 - val_accuracy: 0.4781
# Epoch 14/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6412 - accuracy: 0.6168Restoring model weights from the end of the best epoch: 4.
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6439 - accuracy: 0.6152 - val_loss: 1.1458 - val_accuracy: 0.4701
# Epoch 14: early stopping
# 8/8 [==============================] - 2s 19ms/step
# 8/8 [==============================] - 0s 17ms/step - loss: 1.1530 - accuracy: 0.5777
# RMSE: 1.2529, MAE: 0.8048, ACC: 0.5777, VAL_LOSS: 1.1530
# iteration: [1/20] indiv_no: [5/36]
# Epoch 1/20
# 24/24 [==============================] - 8s 124ms/step - loss: 0.6889 - accuracy: 0.5779 - val_loss: 0.9570 - val_accuracy: 0.5179
# Epoch 2/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6571 - accuracy: 0.5872 - val_loss: 1.0132 - val_accuracy: 0.5418
# Epoch 3/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6509 - accuracy: 0.6085 - val_loss: 1.0745 - val_accuracy: 0.5418
# Epoch 4/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6476 - accuracy: 0.6085 - val_loss: 1.1355 - val_accuracy: 0.5299
# Epoch 5/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6485 - accuracy: 0.6152 - val_loss: 1.0941 - val_accuracy: 0.4781
# Epoch 6/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6515 - accuracy: 0.5952 - val_loss: 1.0306 - val_accuracy: 0.5418
# Epoch 7/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6452 - accuracy: 0.6112 - val_loss: 1.0425 - val_accuracy: 0.5339
# Epoch 8/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6687 - accuracy: 0.5766 - val_loss: 0.9357 - val_accuracy: 0.5179
# Epoch 9/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6488 - accuracy: 0.6005 - val_loss: 1.0670 - val_accuracy: 0.4861
# Epoch 10/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6441 - accuracy: 0.6138 - val_loss: 1.1077 - val_accuracy: 0.5299
# Epoch 11/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6426 - accuracy: 0.6285 - val_loss: 1.1410 - val_accuracy: 0.4940
# Epoch 12/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6405 - accuracy: 0.6046Restoring model weights from the end of the best epoch: 2.
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6430 - accuracy: 0.6032 - val_loss: 1.0724 - val_accuracy: 0.5060
# Epoch 12: early stopping
# 8/8 [==============================] - 1s 15ms/step
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0132 - accuracy: 0.5418
# RMSE: 1.3089, MAE: 0.8765, ACC: 0.5418, VAL_LOSS: 1.0132
# iteration: [1/20] indiv_no: [6/36]
# Epoch 1/20
# 24/24 [==============================] - 6s 101ms/step - loss: 0.7461 - accuracy: 0.5726 - val_loss: 1.0622 - val_accuracy: 0.4542
# Epoch 2/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6528 - accuracy: 0.5939 - val_loss: 1.1438 - val_accuracy: 0.5339
# Epoch 3/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6468 - accuracy: 0.6032 - val_loss: 1.2145 - val_accuracy: 0.4781
# Epoch 4/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6429 - accuracy: 0.6045 - val_loss: 1.1970 - val_accuracy: 0.5100
# Epoch 5/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6451 - accuracy: 0.6245 - val_loss: 1.1456 - val_accuracy: 0.5139
# Epoch 6/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6422 - accuracy: 0.6138 - val_loss: 1.1548 - val_accuracy: 0.5219
# Epoch 7/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6406 - accuracy: 0.6285 - val_loss: 1.2334 - val_accuracy: 0.5259
# Epoch 8/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6380 - accuracy: 0.6298 - val_loss: 1.2012 - val_accuracy: 0.5139
# Epoch 9/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6406 - accuracy: 0.6178 - val_loss: 1.2310 - val_accuracy: 0.5179
# Epoch 10/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6529 - accuracy: 0.6019 - val_loss: 1.0591 - val_accuracy: 0.4502
# Epoch 11/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6520 - accuracy: 0.6099 - val_loss: 1.1784 - val_accuracy: 0.5418
# Epoch 12/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6422 - accuracy: 0.6272 - val_loss: 1.1252 - val_accuracy: 0.5139
# Epoch 13/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.6456 - accuracy: 0.6245 - val_loss: 1.1255 - val_accuracy: 0.4980
# Epoch 14/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6368 - accuracy: 0.6112 - val_loss: 1.1644 - val_accuracy: 0.5339
# Epoch 15/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6368 - accuracy: 0.6152 - val_loss: 1.1931 - val_accuracy: 0.5219
# Epoch 16/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6317 - accuracy: 0.6232 - val_loss: 1.3016 - val_accuracy: 0.4900
# Epoch 17/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6306 - accuracy: 0.6258 - val_loss: 1.2145 - val_accuracy: 0.4701
# Epoch 18/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6354 - accuracy: 0.6165 - val_loss: 1.2175 - val_accuracy: 0.5219
# Epoch 19/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.6384 - accuracy: 0.6112 - val_loss: 1.0479 - val_accuracy: 0.4622
# Epoch 20/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6325 - accuracy: 0.6232 - val_loss: 1.2000 - val_accuracy: 0.5100
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1784 - accuracy: 0.5418
# RMSE: 1.3089, MAE: 0.8765, ACC: 0.5418, VAL_LOSS: 1.1784
# iteration: [1/20] indiv_no: [7/36]
# Epoch 1/20
# 24/24 [==============================] - 8s 112ms/step - loss: 0.6552 - accuracy: 0.6059 - val_loss: 1.0484 - val_accuracy: 0.4821
# Epoch 2/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6461 - accuracy: 0.6232 - val_loss: 1.0816 - val_accuracy: 0.5179
# Epoch 3/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6451 - accuracy: 0.6152 - val_loss: 1.0233 - val_accuracy: 0.4741
# Epoch 4/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6516 - accuracy: 0.5992 - val_loss: 1.0760 - val_accuracy: 0.5458
# Epoch 5/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6423 - accuracy: 0.6045 - val_loss: 1.0776 - val_accuracy: 0.4821
# Epoch 6/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6376 - accuracy: 0.6218 - val_loss: 1.1254 - val_accuracy: 0.5179
# Epoch 7/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6447 - accuracy: 0.5939 - val_loss: 1.0766 - val_accuracy: 0.5179
# Epoch 8/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6380 - accuracy: 0.6285 - val_loss: 1.0934 - val_accuracy: 0.5538
# Epoch 9/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6366 - accuracy: 0.6125 - val_loss: 1.1442 - val_accuracy: 0.5060
# Epoch 10/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6326 - accuracy: 0.6338 - val_loss: 1.1436 - val_accuracy: 0.5179
# Epoch 11/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6333 - accuracy: 0.6178 - val_loss: 1.1654 - val_accuracy: 0.5418
# Epoch 12/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6463 - accuracy: 0.6152 - val_loss: 1.1300 - val_accuracy: 0.5100
# Epoch 13/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6399 - accuracy: 0.6019 - val_loss: 1.1790 - val_accuracy: 0.5100
# Epoch 14/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6384 - accuracy: 0.6125 - val_loss: 1.1507 - val_accuracy: 0.4861
# Epoch 15/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6368 - accuracy: 0.6218 - val_loss: 1.1526 - val_accuracy: 0.5777
# Epoch 16/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6340 - accuracy: 0.6138 - val_loss: 1.1836 - val_accuracy: 0.4701
# Epoch 17/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6403 - accuracy: 0.6005 - val_loss: 1.1167 - val_accuracy: 0.4622
# Epoch 18/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6310 - accuracy: 0.6285 - val_loss: 1.1508 - val_accuracy: 0.5179
# Epoch 19/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6272 - accuracy: 0.6298 - val_loss: 1.1589 - val_accuracy: 0.4223
# Epoch 20/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6298 - accuracy: 0.6192 - val_loss: 1.1090 - val_accuracy: 0.5458
# 8/8 [==============================] - 1s 17ms/step
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1526 - accuracy: 0.5777
# RMSE: 1.2529, MAE: 0.8048, ACC: 0.5777, VAL_LOSS: 1.1526
# iteration: [1/20] indiv_no: [8/36]
# Epoch 1/20
# 24/24 [==============================] - 6s 95ms/step - loss: 0.7673 - accuracy: 0.5726 - val_loss: 0.9618 - val_accuracy: 0.4343
# Epoch 2/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6417 - accuracy: 0.5806 - val_loss: 1.1025 - val_accuracy: 0.5100
# Epoch 3/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6344 - accuracy: 0.6099 - val_loss: 1.1307 - val_accuracy: 0.5139
# Epoch 4/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6347 - accuracy: 0.6099 - val_loss: 1.1419 - val_accuracy: 0.5139
# Epoch 5/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6357 - accuracy: 0.6072 - val_loss: 1.1470 - val_accuracy: 0.4781
# Epoch 6/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6374 - accuracy: 0.6178 - val_loss: 1.0444 - val_accuracy: 0.5418
# Epoch 7/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6355 - accuracy: 0.6072 - val_loss: 1.1043 - val_accuracy: 0.4542
# Epoch 8/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6329 - accuracy: 0.6072 - val_loss: 1.1237 - val_accuracy: 0.5060
# Epoch 9/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6287 - accuracy: 0.6205 - val_loss: 1.1310 - val_accuracy: 0.5378
# Epoch 10/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6373 - accuracy: 0.5992 - val_loss: 1.0513 - val_accuracy: 0.4263
# Epoch 11/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6362 - accuracy: 0.6072 - val_loss: 1.0098 - val_accuracy: 0.5378
# Epoch 12/20
# 24/24 [==============================] - 1s 44ms/step - loss: 0.6315 - accuracy: 0.6045 - val_loss: 1.1062 - val_accuracy: 0.5458
# Epoch 13/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6277 - accuracy: 0.6352 - val_loss: 1.1922 - val_accuracy: 0.5498
# Epoch 14/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6271 - accuracy: 0.6405 - val_loss: 1.1985 - val_accuracy: 0.4940
# Epoch 15/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6318 - accuracy: 0.6312 - val_loss: 1.1587 - val_accuracy: 0.4900
# Epoch 16/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6302 - accuracy: 0.6232 - val_loss: 1.1136 - val_accuracy: 0.4940
# Epoch 17/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6260 - accuracy: 0.6312 - val_loss: 1.2258 - val_accuracy: 0.5458
# Epoch 18/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6360 - accuracy: 0.6192 - val_loss: 1.2069 - val_accuracy: 0.4422
# Epoch 19/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6231 - accuracy: 0.6298 - val_loss: 1.1454 - val_accuracy: 0.5179
# Epoch 20/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6242 - accuracy: 0.6125 - val_loss: 1.1673 - val_accuracy: 0.4462
# 8/8 [==============================] - 1s 13ms/step
# 8/8 [==============================] - 0s 15ms/step - loss: 1.1922 - accuracy: 0.5498
# RMSE: 1.2966, MAE: 0.8606, ACC: 0.5498, VAL_LOSS: 1.1922
# iteration: [1/20] indiv_no: [9/36]
# Epoch 1/20
# 24/24 [==============================] - 15s 116ms/step - loss: 0.7053 - accuracy: 0.6125 - val_loss: 0.9861 - val_accuracy: 0.4303
# Epoch 2/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6396 - accuracy: 0.6125 - val_loss: 1.0932 - val_accuracy: 0.5259
# Epoch 3/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6330 - accuracy: 0.6152 - val_loss: 1.1301 - val_accuracy: 0.5458
# Epoch 4/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6317 - accuracy: 0.6085 - val_loss: 1.2134 - val_accuracy: 0.4940
# Epoch 5/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6282 - accuracy: 0.6285 - val_loss: 1.1741 - val_accuracy: 0.5020
# Epoch 6/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6314 - accuracy: 0.6152 - val_loss: 1.1512 - val_accuracy: 0.5299
# Epoch 7/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6311 - accuracy: 0.6178 - val_loss: 1.0779 - val_accuracy: 0.5299
# Epoch 8/20
# 24/24 [==============================] - 1s 40ms/step - loss: 0.6245 - accuracy: 0.6285 - val_loss: 1.1149 - val_accuracy: 0.5418
# Epoch 9/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6224 - accuracy: 0.6298 - val_loss: 1.2293 - val_accuracy: 0.5020
# Epoch 10/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6227 - accuracy: 0.6218 - val_loss: 1.2367 - val_accuracy: 0.5339
# Epoch 11/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.6283 - accuracy: 0.6205 - val_loss: 1.1610 - val_accuracy: 0.5219
# Epoch 12/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.6194 - accuracy: 0.6338 - val_loss: 1.1934 - val_accuracy: 0.5060
# Epoch 13/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6187 - accuracy: 0.6405Restoring model weights from the end of the best epoch: 3.
# 24/24 [==============================] - 2s 98ms/step - loss: 0.6187 - accuracy: 0.6405 - val_loss: 1.2135 - val_accuracy: 0.4622
# Epoch 13: early stopping
# 8/8 [==============================] - 2s 16ms/step
# 8/8 [==============================] - 0s 26ms/step - loss: 1.1301 - accuracy: 0.5458
# RMSE: 1.3028, MAE: 0.8685, ACC: 0.5458, VAL_LOSS: 1.1301
# iteration: [1/20] indiv_no: [10/36]
# Epoch 1/20
# 24/24 [==============================] - 8s 139ms/step - loss: 0.6629 - accuracy: 0.5992 - val_loss: 1.0016 - val_accuracy: 0.4382
# Epoch 2/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6537 - accuracy: 0.6165 - val_loss: 1.0864 - val_accuracy: 0.5538
# Epoch 3/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6435 - accuracy: 0.6059 - val_loss: 1.1722 - val_accuracy: 0.5179
# Epoch 4/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6499 - accuracy: 0.6152 - val_loss: 1.0907 - val_accuracy: 0.4502
# Epoch 5/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6427 - accuracy: 0.6312 - val_loss: 1.1102 - val_accuracy: 0.5458
# Epoch 6/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6367 - accuracy: 0.6165 - val_loss: 1.1242 - val_accuracy: 0.4582
# Epoch 7/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6431 - accuracy: 0.6072 - val_loss: 1.1266 - val_accuracy: 0.4940
# Epoch 8/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6434 - accuracy: 0.6099 - val_loss: 1.1192 - val_accuracy: 0.4582
# Epoch 9/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6465 - accuracy: 0.5965 - val_loss: 1.0897 - val_accuracy: 0.5100
# Epoch 10/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6405 - accuracy: 0.5992 - val_loss: 1.1283 - val_accuracy: 0.5020
# Epoch 11/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6417 - accuracy: 0.6272 - val_loss: 1.0890 - val_accuracy: 0.4980
# Epoch 12/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6392 - accuracy: 0.5992Restoring model weights from the end of the best epoch: 2.
# 24/24 [==============================] - 1s 56ms/step - loss: 0.6378 - accuracy: 0.6019 - val_loss: 1.1448 - val_accuracy: 0.4861
# Epoch 12: early stopping
# 8/8 [==============================] - 1s 18ms/step
# 8/8 [==============================] - 0s 19ms/step - loss: 1.0864 - accuracy: 0.5538
# RMSE: 1.2905, MAE: 0.8526, ACC: 0.5538, VAL_LOSS: 1.0864
# iteration: [1/20] indiv_no: [11/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 134ms/step - loss: 0.7104 - accuracy: 0.5672 - val_loss: 0.9842 - val_accuracy: 0.4502
# Epoch 2/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6379 - accuracy: 0.6019 - val_loss: 1.1506 - val_accuracy: 0.5139
# Epoch 3/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6398 - accuracy: 0.5965 - val_loss: 1.1468 - val_accuracy: 0.4861
# Epoch 4/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.6366 - accuracy: 0.6019 - val_loss: 1.1029 - val_accuracy: 0.5259
# Epoch 5/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6340 - accuracy: 0.6218 - val_loss: 1.1496 - val_accuracy: 0.5299
# Epoch 6/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6311 - accuracy: 0.6272 - val_loss: 1.1841 - val_accuracy: 0.5259
# Epoch 7/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6329 - accuracy: 0.6085 - val_loss: 1.1068 - val_accuracy: 0.5259
# Epoch 8/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6430 - accuracy: 0.6112 - val_loss: 1.0602 - val_accuracy: 0.5458
# Epoch 9/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6327 - accuracy: 0.6032 - val_loss: 1.0288 - val_accuracy: 0.4980
# Epoch 10/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6353 - accuracy: 0.6085 - val_loss: 1.0844 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.6300 - accuracy: 0.6138 - val_loss: 1.1462 - val_accuracy: 0.4741
# Epoch 12/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6285 - accuracy: 0.6352 - val_loss: 1.2183 - val_accuracy: 0.5378
# Epoch 13/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6288 - accuracy: 0.6285 - val_loss: 1.2532 - val_accuracy: 0.4900
# Epoch 14/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6341 - accuracy: 0.6338 - val_loss: 1.1619 - val_accuracy: 0.5060
# Epoch 15/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6294 - accuracy: 0.6205 - val_loss: 1.1889 - val_accuracy: 0.4582
# Epoch 16/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6252 - accuracy: 0.6325 - val_loss: 1.2581 - val_accuracy: 0.4980
# Epoch 17/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6239 - accuracy: 0.6325 - val_loss: 1.2164 - val_accuracy: 0.5179
# Epoch 18/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6271 - accuracy: 0.6304Restoring model weights from the end of the best epoch: 8.
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6274 - accuracy: 0.6298 - val_loss: 1.2120 - val_accuracy: 0.5219
# Epoch 18: early stopping
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 15ms/step - loss: 1.0602 - accuracy: 0.5458
# RMSE: 1.3028, MAE: 0.8685, ACC: 0.5458, VAL_LOSS: 1.0602
# iteration: [1/20] indiv_no: [12/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 97ms/step - loss: 0.6650 - accuracy: 0.6232 - val_loss: 0.9821 - val_accuracy: 0.4582
# Epoch 2/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6335 - accuracy: 0.6099 - val_loss: 1.1105 - val_accuracy: 0.5458
# Epoch 3/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6383 - accuracy: 0.6258 - val_loss: 1.1168 - val_accuracy: 0.4502
# Epoch 4/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6368 - accuracy: 0.6138 - val_loss: 1.1078 - val_accuracy: 0.5618
# Epoch 5/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6345 - accuracy: 0.6125 - val_loss: 1.1134 - val_accuracy: 0.4422
# Epoch 6/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6351 - accuracy: 0.6099 - val_loss: 1.1405 - val_accuracy: 0.5139
# Epoch 7/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6392 - accuracy: 0.6205 - val_loss: 1.0973 - val_accuracy: 0.4661
# Epoch 8/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6388 - accuracy: 0.6125 - val_loss: 1.1231 - val_accuracy: 0.5737
# Epoch 9/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6386 - accuracy: 0.6125 - val_loss: 1.1270 - val_accuracy: 0.4980
# Epoch 10/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6294 - accuracy: 0.6218 - val_loss: 1.1693 - val_accuracy: 0.4502
# Epoch 11/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6358 - accuracy: 0.6285 - val_loss: 1.1206 - val_accuracy: 0.4382
# Epoch 12/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6446 - accuracy: 0.6138 - val_loss: 1.0992 - val_accuracy: 0.4622
# Epoch 13/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6349 - accuracy: 0.6218 - val_loss: 1.1884 - val_accuracy: 0.4382
# Epoch 14/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6288 - accuracy: 0.6312 - val_loss: 1.2016 - val_accuracy: 0.5179
# Epoch 15/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6316 - accuracy: 0.6298 - val_loss: 1.1795 - val_accuracy: 0.5339
# Epoch 16/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6261 - accuracy: 0.6152 - val_loss: 1.1516 - val_accuracy: 0.4701
# Epoch 17/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6374 - accuracy: 0.6085 - val_loss: 1.0755 - val_accuracy: 0.4422
# Epoch 18/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6284 - accuracy: 0.6298 - val_loss: 1.0998 - val_accuracy: 0.5777
# Epoch 19/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6496 - accuracy: 0.6099 - val_loss: 1.0761 - val_accuracy: 0.5179
# Epoch 20/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.6290 - accuracy: 0.6152 - val_loss: 1.1862 - val_accuracy: 0.5060
# 8/8 [==============================] - 2s 17ms/step
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0998 - accuracy: 0.5777
# RMSE: 1.2529, MAE: 0.8048, ACC: 0.5777, VAL_LOSS: 1.0998
# iteration: [1/20] indiv_no: [13/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 107ms/step - loss: 0.6870 - accuracy: 0.5965 - val_loss: 0.9950 - val_accuracy: 0.4821
# Epoch 2/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6428 - accuracy: 0.5952 - val_loss: 1.0456 - val_accuracy: 0.5378
# Epoch 3/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6399 - accuracy: 0.6232 - val_loss: 1.0776 - val_accuracy: 0.5339
# Epoch 4/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.6414 - accuracy: 0.6138 - val_loss: 1.0656 - val_accuracy: 0.4900
# Epoch 5/20
# 24/24 [==============================] - 2s 74ms/step - loss: 0.6374 - accuracy: 0.6298 - val_loss: 1.0380 - val_accuracy: 0.5299
# Epoch 6/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6379 - accuracy: 0.6312 - val_loss: 1.0535 - val_accuracy: 0.5179
# Epoch 7/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6328 - accuracy: 0.6258 - val_loss: 1.1191 - val_accuracy: 0.5498
# Epoch 8/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6346 - accuracy: 0.6272 - val_loss: 1.1787 - val_accuracy: 0.5100
# Epoch 9/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6349 - accuracy: 0.6152 - val_loss: 1.1227 - val_accuracy: 0.4900
# Epoch 10/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6276 - accuracy: 0.6378 - val_loss: 1.0810 - val_accuracy: 0.5418
# Epoch 11/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6268 - accuracy: 0.6258 - val_loss: 1.1532 - val_accuracy: 0.4900
# Epoch 12/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.6325 - accuracy: 0.6232 - val_loss: 1.1754 - val_accuracy: 0.4900
# Epoch 13/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6234 - accuracy: 0.6165 - val_loss: 1.1205 - val_accuracy: 0.5378
# Epoch 14/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6278 - accuracy: 0.6312 - val_loss: 1.1350 - val_accuracy: 0.4980
# Epoch 15/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6249 - accuracy: 0.6325 - val_loss: 1.1608 - val_accuracy: 0.5299
# Epoch 16/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6262 - accuracy: 0.6365 - val_loss: 1.2119 - val_accuracy: 0.4980
# Epoch 17/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6266 - accuracy: 0.6359Restoring model weights from the end of the best epoch: 7.
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6258 - accuracy: 0.6338 - val_loss: 1.1633 - val_accuracy: 0.5259
# Epoch 17: early stopping
# 8/8 [==============================] - 1s 13ms/step
# 8/8 [==============================] - 0s 16ms/step - loss: 1.1191 - accuracy: 0.5498
# RMSE: 1.2966, MAE: 0.8606, ACC: 0.5498, VAL_LOSS: 1.1191
# iteration: [1/20] indiv_no: [14/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 112ms/step - loss: 0.6588 - accuracy: 0.5979 - val_loss: 0.9993 - val_accuracy: 0.4622
# Epoch 2/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6504 - accuracy: 0.6152 - val_loss: 1.0943 - val_accuracy: 0.5339
# Epoch 3/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6482 - accuracy: 0.6085 - val_loss: 1.0645 - val_accuracy: 0.5100
# Epoch 4/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6436 - accuracy: 0.6245 - val_loss: 1.0655 - val_accuracy: 0.5458
# Epoch 5/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6454 - accuracy: 0.6218 - val_loss: 1.0877 - val_accuracy: 0.5060
# Epoch 6/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6492 - accuracy: 0.6138 - val_loss: 0.9973 - val_accuracy: 0.4940
# Epoch 7/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6448 - accuracy: 0.6085 - val_loss: 1.0162 - val_accuracy: 0.5458
# Epoch 8/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6460 - accuracy: 0.6019 - val_loss: 1.0591 - val_accuracy: 0.5378
# Epoch 9/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6550 - accuracy: 0.5925 - val_loss: 1.0259 - val_accuracy: 0.5618
# Epoch 10/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6561 - accuracy: 0.6125 - val_loss: 1.0575 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6490 - accuracy: 0.6059 - val_loss: 1.0341 - val_accuracy: 0.5020
# Epoch 12/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6423 - accuracy: 0.6138 - val_loss: 1.0260 - val_accuracy: 0.5458
# Epoch 13/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6368 - accuracy: 0.6125 - val_loss: 1.0513 - val_accuracy: 0.5339
# Epoch 14/20
# 24/24 [==============================] - 2s 71ms/step - loss: 0.6422 - accuracy: 0.6258 - val_loss: 1.0822 - val_accuracy: 0.5020
# Epoch 15/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.6403 - accuracy: 0.6325 - val_loss: 1.0544 - val_accuracy: 0.5060
# Epoch 16/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.6365 - accuracy: 0.6258 - val_loss: 1.0872 - val_accuracy: 0.5538
# Epoch 17/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.6388 - accuracy: 0.6125 - val_loss: 1.0050 - val_accuracy: 0.5020
# Epoch 18/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6343 - accuracy: 0.6258 - val_loss: 1.0913 - val_accuracy: 0.5498
# Epoch 19/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6388 - accuracy: 0.6223Restoring model weights from the end of the best epoch: 9.
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6374 - accuracy: 0.6232 - val_loss: 1.1018 - val_accuracy: 0.5060
# Epoch 19: early stopping
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 21ms/step - loss: 1.0259 - accuracy: 0.5618
# RMSE: 1.2781, MAE: 0.8367, ACC: 0.5618, VAL_LOSS: 1.0259
# iteration: [1/20] indiv_no: [15/36]
# Epoch 1/20
# 24/24 [==============================] - 11s 110ms/step - loss: 0.6910 - accuracy: 0.6005 - val_loss: 0.9796 - val_accuracy: 0.4781
# Epoch 2/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6586 - accuracy: 0.6125 - val_loss: 1.0825 - val_accuracy: 0.5060
# Epoch 3/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6553 - accuracy: 0.6138 - val_loss: 1.0479 - val_accuracy: 0.4980
# Epoch 4/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6554 - accuracy: 0.6112 - val_loss: 1.0497 - val_accuracy: 0.5139
# Epoch 5/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6584 - accuracy: 0.6072 - val_loss: 0.9958 - val_accuracy: 0.4900
# Epoch 6/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6562 - accuracy: 0.6045 - val_loss: 1.0469 - val_accuracy: 0.4980
# Epoch 7/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6577 - accuracy: 0.6045 - val_loss: 1.0205 - val_accuracy: 0.5100
# Epoch 8/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6570 - accuracy: 0.6045 - val_loss: 0.9861 - val_accuracy: 0.4940
# Epoch 9/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6589 - accuracy: 0.6059 - val_loss: 1.0953 - val_accuracy: 0.5060
# Epoch 10/20
# 24/24 [==============================] - 1s 63ms/step - loss: 0.6557 - accuracy: 0.5965 - val_loss: 1.0557 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6625 - accuracy: 0.5752 - val_loss: 0.9695 - val_accuracy: 0.4741
# Epoch 12/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.6558 - accuracy: 0.6125 - val_loss: 1.0398 - val_accuracy: 0.4940
# Epoch 13/20
# 24/24 [==============================] - 2s 75ms/step - loss: 0.6528 - accuracy: 0.6032 - val_loss: 1.0552 - val_accuracy: 0.4980
# Epoch 14/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.6589 - accuracy: 0.5992 - val_loss: 1.0456 - val_accuracy: 0.4622
# Epoch 15/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6558 - accuracy: 0.6019 - val_loss: 1.0763 - val_accuracy: 0.5060
# Epoch 16/20
# 24/24 [==============================] - 1s 55ms/step - loss: 0.6546 - accuracy: 0.5965 - val_loss: 1.1026 - val_accuracy: 0.4861
# Epoch 17/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.6520 - accuracy: 0.6072 - val_loss: 1.0444 - val_accuracy: 0.5020
# Epoch 18/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6514 - accuracy: 0.6165 - val_loss: 1.0863 - val_accuracy: 0.4940
# Epoch 19/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.6526 - accuracy: 0.6045 - val_loss: 1.0744 - val_accuracy: 0.5139
# Epoch 20/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6534 - accuracy: 0.6073Restoring model weights from the end of the best epoch: 10.
# 24/24 [==============================] - 1s 45ms/step - loss: 0.6536 - accuracy: 0.6072 - val_loss: 1.0453 - val_accuracy: 0.4701
# Epoch 20: early stopping
# 8/8 [==============================] - 1s 18ms/step
# 8/8 [==============================] - 0s 18ms/step - loss: 1.0557 - accuracy: 0.5219
# RMSE: 1.3390, MAE: 0.9163, ACC: 0.5219, VAL_LOSS: 1.0557
# iteration: [1/20] indiv_no: [16/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 84ms/step - loss: 0.7139 - accuracy: 0.5859 - val_loss: 1.0123 - val_accuracy: 0.4303
# Epoch 2/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6384 - accuracy: 0.6298 - val_loss: 1.1244 - val_accuracy: 0.5458
# Epoch 3/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6379 - accuracy: 0.6112 - val_loss: 1.1808 - val_accuracy: 0.5179
# Epoch 4/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6343 - accuracy: 0.6072 - val_loss: 1.1895 - val_accuracy: 0.5578
# Epoch 5/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6338 - accuracy: 0.5979 - val_loss: 1.0983 - val_accuracy: 0.5299
# Epoch 6/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6340 - accuracy: 0.6059 - val_loss: 1.1841 - val_accuracy: 0.4821
# Epoch 7/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6327 - accuracy: 0.6099 - val_loss: 1.1656 - val_accuracy: 0.4701
# Epoch 8/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6381 - accuracy: 0.6125 - val_loss: 1.1321 - val_accuracy: 0.5498
# Epoch 9/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6360 - accuracy: 0.6125 - val_loss: 1.1351 - val_accuracy: 0.4661
# Epoch 10/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6341 - accuracy: 0.6272 - val_loss: 1.0991 - val_accuracy: 0.5418
# Epoch 11/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6269 - accuracy: 0.6218 - val_loss: 1.1315 - val_accuracy: 0.4622
# Epoch 12/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6313 - accuracy: 0.6165 - val_loss: 1.0907 - val_accuracy: 0.4940
# Epoch 13/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6298 - accuracy: 0.6192 - val_loss: 1.1430 - val_accuracy: 0.5299
# Epoch 14/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6261 - accuracy: 0.6182Restoring model weights from the end of the best epoch: 4.
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6251 - accuracy: 0.6218 - val_loss: 1.1884 - val_accuracy: 0.5060
# Epoch 14: early stopping
# 8/8 [==============================] - 1s 17ms/step
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1895 - accuracy: 0.5578
# RMSE: 1.2843, MAE: 0.8446, ACC: 0.5578, VAL_LOSS: 1.1895
# iteration: [1/20] indiv_no: [17/36]
# Epoch 1/20
# 24/24 [==============================] - 6s 87ms/step - loss: 0.6775 - accuracy: 0.5952 - val_loss: 0.9687 - val_accuracy: 0.4661
# Epoch 2/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6397 - accuracy: 0.6059 - val_loss: 1.1227 - val_accuracy: 0.5219
# Epoch 3/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6404 - accuracy: 0.6045 - val_loss: 1.1705 - val_accuracy: 0.5020
# Epoch 4/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6401 - accuracy: 0.6099 - val_loss: 1.1401 - val_accuracy: 0.4900
# Epoch 5/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6407 - accuracy: 0.6099 - val_loss: 1.0538 - val_accuracy: 0.5060
# Epoch 6/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6393 - accuracy: 0.6085 - val_loss: 1.1255 - val_accuracy: 0.5219
# Epoch 7/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6329 - accuracy: 0.6112 - val_loss: 1.1916 - val_accuracy: 0.4900
# Epoch 8/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6378 - accuracy: 0.6112 - val_loss: 1.1605 - val_accuracy: 0.5060
# Epoch 9/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6473 - accuracy: 0.6072 - val_loss: 0.9953 - val_accuracy: 0.4382
# Epoch 10/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6459 - accuracy: 0.6005 - val_loss: 1.0556 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6356 - accuracy: 0.6218 - val_loss: 1.1103 - val_accuracy: 0.4861
# Epoch 12/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6373 - accuracy: 0.6196Restoring model weights from the end of the best epoch: 2.
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6388 - accuracy: 0.6178 - val_loss: 1.2318 - val_accuracy: 0.4582
# Epoch 12: early stopping
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 18ms/step - loss: 1.1227 - accuracy: 0.5219
# RMSE: 1.3390, MAE: 0.9163, ACC: 0.5219, VAL_LOSS: 1.1227
# iteration: [1/20] indiv_no: [18/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 85ms/step - loss: 0.6960 - accuracy: 0.5646 - val_loss: 0.9783 - val_accuracy: 0.4821
# Epoch 2/20
# 24/24 [==============================] - 1s 43ms/step - loss: 0.6499 - accuracy: 0.6152 - val_loss: 1.0284 - val_accuracy: 0.5339
# Epoch 3/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6444 - accuracy: 0.6125 - val_loss: 1.0822 - val_accuracy: 0.5498
# Epoch 4/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6448 - accuracy: 0.6072 - val_loss: 1.0945 - val_accuracy: 0.5179
# Epoch 5/20
# 24/24 [==============================] - 1s 49ms/step - loss: 0.6443 - accuracy: 0.6059 - val_loss: 1.1255 - val_accuracy: 0.4980
# Epoch 6/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.6424 - accuracy: 0.6072 - val_loss: 1.0655 - val_accuracy: 0.5339
# Epoch 7/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.6407 - accuracy: 0.6125 - val_loss: 1.0718 - val_accuracy: 0.5498
# Epoch 8/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.6447 - accuracy: 0.5992 - val_loss: 1.0724 - val_accuracy: 0.4861
# Epoch 9/20
# 24/24 [==============================] - 1s 46ms/step - loss: 0.6500 - accuracy: 0.5952 - val_loss: 1.0284 - val_accuracy: 0.4701
# Epoch 10/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6404 - accuracy: 0.5992 - val_loss: 1.0432 - val_accuracy: 0.5299
# Epoch 11/20
# 24/24 [==============================] - 1s 41ms/step - loss: 0.6435 - accuracy: 0.6072 - val_loss: 1.0983 - val_accuracy: 0.4622
# Epoch 12/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6396 - accuracy: 0.6138 - val_loss: 1.0879 - val_accuracy: 0.5179
# Epoch 13/20
# 23/24 [===========================>..] - ETA: 0s - loss: 0.6325 - accuracy: 0.6304Restoring model weights from the end of the best epoch: 3.
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6338 - accuracy: 0.6285 - val_loss: 1.1732 - val_accuracy: 0.5299
# Epoch 13: early stopping
# 8/8 [==============================] - 1s 16ms/step
# 8/8 [==============================] - 0s 20ms/step - loss: 1.0822 - accuracy: 0.5498
# RMSE: 1.2966, MAE: 0.8606, ACC: 0.5498, VAL_LOSS: 1.0822
# iteration: [1/20] indiv_no: [19/36]
# Epoch 1/20
# 24/24 [==============================] - 7s 85ms/step - loss: 0.7367 - accuracy: 0.5912 - val_loss: 0.9629 - val_accuracy: 0.4462
# Epoch 2/20
# 24/24 [==============================] - 1s 42ms/step - loss: 0.6477 - accuracy: 0.5992 - val_loss: 1.0107 - val_accuracy: 0.5299
# Epoch 3/20
# 24/24 [==============================] - 1s 47ms/step - loss: 0.6421 - accuracy: 0.6032 - val_loss: 1.0554 - val_accuracy: 0.5060
# Epoch 4/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.6391 - accuracy: 0.6112 - val_loss: 1.0702 - val_accuracy: 0.5339
# Epoch 5/20
# 24/24 [==============================] - 1s 51ms/step - loss: 0.6387 - accuracy: 0.6099 - val_loss: 1.0663 - val_accuracy: 0.5139
# Epoch 6/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.6390 - accuracy: 0.6032 - val_loss: 1.0788 - val_accuracy: 0.4980
# Epoch 7/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.6370 - accuracy: 0.5979 - val_loss: 1.0578 - val_accuracy: 0.5418
# Epoch 8/20
# ...
# iteration: [20/20] indiv_no: [31/36]
# Epoch 1/20
# 24/24 [==============================] - 11s 151ms/step - loss: 0.6550 - accuracy: 0.6005 - val_loss: 1.0464 - val_accuracy: 0.4622
# Epoch 2/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.6469 - accuracy: 0.5912 - val_loss: 1.0296 - val_accuracy: 0.5857
# Epoch 3/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6422 - accuracy: 0.6019 - val_loss: 1.0887 - val_accuracy: 0.5458
# Epoch 4/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.6406 - accuracy: 0.6178 - val_loss: 1.1459 - val_accuracy: 0.4781
# Epoch 5/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.6378 - accuracy: 0.6072 - val_loss: 1.0905 - val_accuracy: 0.5538
# Epoch 6/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6370 - accuracy: 0.6085 - val_loss: 1.1378 - val_accuracy: 0.4343
# Epoch 7/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6446 - accuracy: 0.6152 - val_loss: 1.0519 - val_accuracy: 0.5219
# Epoch 8/20
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6374 - accuracy: 0.6165 - val_loss: 1.0577 - val_accuracy: 0.4861
# Epoch 9/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.6382 - accuracy: 0.6218 - val_loss: 1.1244 - val_accuracy: 0.5259
# Epoch 10/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6416 - accuracy: 0.6178 - val_loss: 1.0938 - val_accuracy: 0.5458
# Epoch 11/20
# 24/24 [==============================] - 2s 87ms/step - loss: 0.6446 - accuracy: 0.6032 - val_loss: 1.0652 - val_accuracy: 0.4741
# Epoch 12/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6348 - accuracy: 0.6192Restoring model weights from the end of the best epoch: 2.
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6348 - accuracy: 0.6192 - val_loss: 1.0785 - val_accuracy: 0.4622
# Epoch 12: early stopping
# 8/8 [==============================] - 1s 24ms/step
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0296 - accuracy: 0.5857
# RMSE: 1.2401, MAE: 0.7888, ACC: 0.5857, VAL_LOSS: 1.0296
# iteration: [20/20] indiv_no: [32/36]
# Epoch 1/20
# 24/24 [==============================] - 10s 158ms/step - loss: 0.7545 - accuracy: 0.5819 - val_loss: 1.0370 - val_accuracy: 0.4502
# Epoch 2/20
# 24/24 [==============================] - 2s 94ms/step - loss: 0.6516 - accuracy: 0.6138 - val_loss: 1.0235 - val_accuracy: 0.5139
# Epoch 3/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.6369 - accuracy: 0.6125 - val_loss: 1.1447 - val_accuracy: 0.5060
# Epoch 4/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6341 - accuracy: 0.6112 - val_loss: 1.1070 - val_accuracy: 0.5418
# Epoch 5/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.6281 - accuracy: 0.6338 - val_loss: 1.1328 - val_accuracy: 0.5378
# Epoch 6/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.6263 - accuracy: 0.6338 - val_loss: 1.1658 - val_accuracy: 0.5339
# Epoch 7/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.6320 - accuracy: 0.6152 - val_loss: 1.0665 - val_accuracy: 0.5498
# Epoch 8/20
# 24/24 [==============================] - 3s 114ms/step - loss: 0.6264 - accuracy: 0.6245 - val_loss: 1.0975 - val_accuracy: 0.4741
# Epoch 9/20
# 24/24 [==============================] - 2s 98ms/step - loss: 0.6282 - accuracy: 0.6285 - val_loss: 1.0773 - val_accuracy: 0.5179
# Epoch 10/20
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6245 - accuracy: 0.6298 - val_loss: 1.1043 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.6230 - accuracy: 0.6418 - val_loss: 1.1107 - val_accuracy: 0.5060
# Epoch 12/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6202 - accuracy: 0.6378 - val_loss: 1.1565 - val_accuracy: 0.5299
# Epoch 13/20
# 24/24 [==============================] - 2s 96ms/step - loss: 0.6346 - accuracy: 0.6099 - val_loss: 1.1164 - val_accuracy: 0.4900
# Epoch 14/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6217 - accuracy: 0.6378 - val_loss: 1.1158 - val_accuracy: 0.5299
# Epoch 15/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6187 - accuracy: 0.6352 - val_loss: 1.1409 - val_accuracy: 0.5020
# Epoch 16/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6161 - accuracy: 0.6312 - val_loss: 1.2061 - val_accuracy: 0.5339
# Epoch 17/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6237 - accuracy: 0.6352Restoring model weights from the end of the best epoch: 7.
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6237 - accuracy: 0.6352 - val_loss: 1.1004 - val_accuracy: 0.4701
# Epoch 17: early stopping
# 8/8 [==============================] - 2s 22ms/step
# 8/8 [==============================] - 0s 31ms/step - loss: 1.0665 - accuracy: 0.5498
# RMSE: 1.2966, MAE: 0.8606, ACC: 0.5498, VAL_LOSS: 1.0665
# iteration: [20/20] indiv_no: [33/36]
# Epoch 1/20
# 24/24 [==============================] - 11s 200ms/step - loss: 0.6900 - accuracy: 0.5712 - val_loss: 0.8981 - val_accuracy: 0.4861
# Epoch 2/20
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6408 - accuracy: 0.6138 - val_loss: 1.0285 - val_accuracy: 0.5339
# Epoch 3/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6369 - accuracy: 0.6072 - val_loss: 1.0920 - val_accuracy: 0.5100
# Epoch 4/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.6386 - accuracy: 0.6192 - val_loss: 1.0288 - val_accuracy: 0.5498
# Epoch 5/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.6351 - accuracy: 0.6192 - val_loss: 1.0371 - val_accuracy: 0.5339
# Epoch 6/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6355 - accuracy: 0.6072 - val_loss: 1.0455 - val_accuracy: 0.5378
# Epoch 7/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6295 - accuracy: 0.6431 - val_loss: 1.0817 - val_accuracy: 0.5179
# Epoch 8/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6339 - accuracy: 0.6218 - val_loss: 1.0661 - val_accuracy: 0.4900
# Epoch 9/20
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6287 - accuracy: 0.6325 - val_loss: 1.0659 - val_accuracy: 0.5100
# Epoch 10/20
# 24/24 [==============================] - 2s 96ms/step - loss: 0.6297 - accuracy: 0.6218 - val_loss: 1.0832 - val_accuracy: 0.5219
# Epoch 11/20
# 24/24 [==============================] - 3s 113ms/step - loss: 0.6271 - accuracy: 0.6365 - val_loss: 1.0926 - val_accuracy: 0.5139
# Epoch 12/20
# 24/24 [==============================] - 3s 103ms/step - loss: 0.6239 - accuracy: 0.6272 - val_loss: 1.1356 - val_accuracy: 0.5378
# Epoch 13/20
# 24/24 [==============================] - 2s 99ms/step - loss: 0.6271 - accuracy: 0.6218 - val_loss: 1.1441 - val_accuracy: 0.5339
# Epoch 14/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.6218Restoring model weights from the end of the best epoch: 4.
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6276 - accuracy: 0.6218 - val_loss: 1.0918 - val_accuracy: 0.5139
# Epoch 14: early stopping
# 8/8 [==============================] - 2s 27ms/step
# 8/8 [==============================] - 0s 25ms/step - loss: 1.0288 - accuracy: 0.5498
# RMSE: 1.2966, MAE: 0.8606, ACC: 0.5498, VAL_LOSS: 1.0288
# iteration: [20/20] indiv_no: [34/36]
# Epoch 1/20
# 24/24 [==============================] - 11s 214ms/step - loss: 0.6701 - accuracy: 0.6059 - val_loss: 0.9706 - val_accuracy: 0.4781
# Epoch 2/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6437 - accuracy: 0.6232 - val_loss: 1.0847 - val_accuracy: 0.5020
# Epoch 3/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.6491 - accuracy: 0.6099 - val_loss: 0.9946 - val_accuracy: 0.5100
# Epoch 4/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.6446 - accuracy: 0.6099 - val_loss: 1.0766 - val_accuracy: 0.4701
# Epoch 5/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.6422 - accuracy: 0.6059 - val_loss: 1.0323 - val_accuracy: 0.5139
# Epoch 6/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.6426 - accuracy: 0.6192 - val_loss: 1.0680 - val_accuracy: 0.4940
# Epoch 7/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.6434 - accuracy: 0.6019 - val_loss: 1.0725 - val_accuracy: 0.5139
# Epoch 8/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6366 - accuracy: 0.6165 - val_loss: 1.0876 - val_accuracy: 0.5060
# Epoch 9/20
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6374 - accuracy: 0.6099 - val_loss: 1.1145 - val_accuracy: 0.4422
# Epoch 10/20
# 24/24 [==============================] - 2s 96ms/step - loss: 0.6382 - accuracy: 0.6059 - val_loss: 1.0647 - val_accuracy: 0.5139
# Epoch 11/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.6344 - accuracy: 0.6165 - val_loss: 1.1242 - val_accuracy: 0.4900
# Epoch 12/20
# 24/24 [==============================] - 2s 83ms/step - loss: 0.6355 - accuracy: 0.6138 - val_loss: 1.1210 - val_accuracy: 0.5060
# Epoch 13/20
# 24/24 [==============================] - 2s 93ms/step - loss: 0.6350 - accuracy: 0.6125 - val_loss: 1.1693 - val_accuracy: 0.4661
# Epoch 14/20
# 24/24 [==============================] - 2s 86ms/step - loss: 0.6291 - accuracy: 0.6125 - val_loss: 1.2159 - val_accuracy: 0.4980
# Epoch 15/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6125Restoring model weights from the end of the best epoch: 5.
# 24/24 [==============================] - 2s 94ms/step - loss: 0.6358 - accuracy: 0.6125 - val_loss: 1.1843 - val_accuracy: 0.4622
# Epoch 15: early stopping
# 8/8 [==============================] - 2s 27ms/step
# 8/8 [==============================] - 0s 29ms/step - loss: 1.0323 - accuracy: 0.5139
# RMSE: 1.3508, MAE: 0.9323, ACC: 0.5139, VAL_LOSS: 1.0323
# iteration: [20/20] indiv_no: [35/36]
# Epoch 1/20
# 24/24 [==============================] - 9s 168ms/step - loss: 0.7405 - accuracy: 0.5885 - val_loss: 1.0379 - val_accuracy: 0.4343
# Epoch 2/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.6431 - accuracy: 0.6192 - val_loss: 0.9821 - val_accuracy: 0.5179
# Epoch 3/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6375 - accuracy: 0.6205 - val_loss: 1.1002 - val_accuracy: 0.5060
# Epoch 4/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6386 - accuracy: 0.6112 - val_loss: 1.1340 - val_accuracy: 0.5179
# Epoch 5/20
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6361 - accuracy: 0.6085 - val_loss: 1.1155 - val_accuracy: 0.4861
# Epoch 6/20
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6320 - accuracy: 0.6152 - val_loss: 1.0863 - val_accuracy: 0.5219
# Epoch 7/20
# 24/24 [==============================] - 2s 101ms/step - loss: 0.6312 - accuracy: 0.6152 - val_loss: 1.1267 - val_accuracy: 0.5219
# Epoch 8/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.6275 - accuracy: 0.6312 - val_loss: 1.1280 - val_accuracy: 0.4701
# Epoch 9/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6261 - accuracy: 0.6285 - val_loss: 1.1508 - val_accuracy: 0.5418
# Epoch 10/20
# 24/24 [==============================] - 2s 94ms/step - loss: 0.6293 - accuracy: 0.6245 - val_loss: 1.1119 - val_accuracy: 0.5139
# Epoch 11/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6328 - accuracy: 0.6445 - val_loss: 1.1198 - val_accuracy: 0.4582
# Epoch 12/20
# 24/24 [==============================] - 2s 104ms/step - loss: 0.6259 - accuracy: 0.6165 - val_loss: 1.1094 - val_accuracy: 0.5259
# Epoch 13/20
# 24/24 [==============================] - 2s 103ms/step - loss: 0.6219 - accuracy: 0.6418 - val_loss: 1.1323 - val_accuracy: 0.5139
# Epoch 14/20
# 24/24 [==============================] - 2s 100ms/step - loss: 0.6240 - accuracy: 0.6272 - val_loss: 1.1235 - val_accuracy: 0.4940
# Epoch 15/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.6223 - accuracy: 0.6272 - val_loss: 1.1107 - val_accuracy: 0.4980
# Epoch 16/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6239 - accuracy: 0.6352 - val_loss: 1.1255 - val_accuracy: 0.5060
# Epoch 17/20
# 24/24 [==============================] - 3s 128ms/step - loss: 0.6190 - accuracy: 0.6365 - val_loss: 1.1837 - val_accuracy: 0.4821
# Epoch 18/20
# 24/24 [==============================] - 3s 104ms/step - loss: 0.6213 - accuracy: 0.6325 - val_loss: 1.0742 - val_accuracy: 0.5179
# Epoch 19/20
# 24/24 [==============================] - ETA: 0s - loss: 0.6136 - accuracy: 0.6511Restoring model weights from the end of the best epoch: 9.
# 24/24 [==============================] - 2s 98ms/step - loss: 0.6136 - accuracy: 0.6511 - val_loss: 1.1732 - val_accuracy: 0.4701
# Epoch 19: early stopping
# 8/8 [==============================] - 2s 28ms/step
# 8/8 [==============================] - 0s 29ms/step - loss: 1.1508 - accuracy: 0.5418
# RMSE: 1.3089, MAE: 0.8765, ACC: 0.5418, VAL_LOSS: 1.1508
# iteration: [20/20] indiv_no: [36/36]
# Epoch 1/20
# 24/24 [==============================] - 10s 161ms/step - loss: 0.6660 - accuracy: 0.5925 - val_loss: 0.9821 - val_accuracy: 0.4980
# Epoch 2/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6567 - accuracy: 0.6005 - val_loss: 0.9957 - val_accuracy: 0.4861
# Epoch 3/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.6566 - accuracy: 0.6045 - val_loss: 0.9727 - val_accuracy: 0.5259
# Epoch 4/20
# 24/24 [==============================] - 2s 102ms/step - loss: 0.6588 - accuracy: 0.5952 - val_loss: 1.0384 - val_accuracy: 0.4940
# Epoch 5/20
# 24/24 [==============================] - 2s 96ms/step - loss: 0.6510 - accuracy: 0.5952 - val_loss: 0.9985 - val_accuracy: 0.5378
# Epoch 6/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.6503 - accuracy: 0.6152 - val_loss: 1.0317 - val_accuracy: 0.4741
# Epoch 7/20
# 24/24 [==============================] - 2s 85ms/step - loss: 0.6578 - accuracy: 0.5912 - val_loss: 1.0918 - val_accuracy: 0.5020
# Epoch 8/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6513 - accuracy: 0.6232 - val_loss: 1.0160 - val_accuracy: 0.5299
# Epoch 9/20
# 24/24 [==============================] - 2s 77ms/step - loss: 0.6501 - accuracy: 0.6152 - val_loss: 1.0108 - val_accuracy: 0.4861
# Epoch 10/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.6488 - accuracy: 0.6192 - val_loss: 1.0558 - val_accuracy: 0.5339
# Epoch 11/20
# 24/24 [==============================] - 2s 91ms/step - loss: 0.6579 - accuracy: 0.5925 - val_loss: 0.9543 - val_accuracy: 0.4422
# Epoch 12/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6532 - accuracy: 0.5979 - val_loss: 1.0275 - val_accuracy: 0.5100
# Epoch 13/20
# 24/24 [==============================] - 2s 88ms/step - loss: 0.6494 - accuracy: 0.6165 - val_loss: 1.0706 - val_accuracy: 0.5179
# Epoch 14/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6475 - accuracy: 0.6138 - val_loss: 1.0758 - val_accuracy: 0.5418
# Epoch 15/20
# 24/24 [==============================] - 2s 76ms/step - loss: 0.6488 - accuracy: 0.6152 - val_loss: 1.0552 - val_accuracy: 0.5259
# Epoch 16/20
# 24/24 [==============================] - 2s 94ms/step - loss: 0.6511 - accuracy: 0.5965 - val_loss: 1.0246 - val_accuracy: 0.4821
# Epoch 17/20
# 24/24 [==============================] - 2s 92ms/step - loss: 0.6448 - accuracy: 0.6152 - val_loss: 1.0708 - val_accuracy: 0.5060
# Epoch 18/20
# 24/24 [==============================] - 2s 89ms/step - loss: 0.6471 - accuracy: 0.6152 - val_loss: 1.1082 - val_accuracy: 0.4980
# Epoch 19/20
# 24/24 [==============================] - 2s 84ms/step - loss: 0.6424 - accuracy: 0.6245 - val_loss: 1.0765 - val_accuracy: 0.5060
# Epoch 20/20
# 24/24 [==============================] - 2s 78ms/step - loss: 0.6400 - accuracy: 0.6032 - val_loss: 1.1037 - val_accuracy: 0.5060
# 8/8 [==============================] - 1s 20ms/step
# 8/8 [==============================] - 0s 22ms/step - loss: 1.0758 - accuracy: 0.5418
# RMSE: 1.3089, MAE: 0.8765, ACC: 0.5418, VAL_LOSS: 1.0758

# %%
def test_eval(model,weight,X,y,ycat):
    print('test evaluation:')
    pred_y = model.predict(apply_weight(X, weight))
    inv_pred_y = np.argmax(pred_y, axis=1)
    inv_test_y = y
    rmse = sqrt(mean_squared_error(inv_test_y, inv_pred_y))
    mae = mean_absolute_error(inv_test_y, inv_pred_y)
    val_loss, acc = model.evaluate(apply_weight(X, weight), ycat)
    print("RMSE: %.4f, MAE: %.4f, ACC: %.4f, VAL_LOSS: %.4f" % (rmse, mae, acc, val_loss))

# %%
test_eval(best_model,best_weight,X_test1,y_test1,y_testcat)
# Out:
# test evaluation:
# 8/8 [==============================] - 2s 18ms/step
# 8/8 [==============================] - 2s 13ms/step - loss: 1.1501 - accuracy: 0.6255
# RMSE: 1.1741, MAE: 0.7092, ACC: 0.6255, VAL_LOSS: 1.1501

# %%
#saving the model
save_model(best_model, "models/best_ealstm/") #acc 0.6255 rmse 1.1741
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_18_layer_call_fn, lstm_cell_18_layer_call_and_return_conditional_losses, lstm_cell_19_layer_call_fn, lstm_cell_19_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/best_ealstm/assets
# INFO:tensorflow:Assets written to: models/best_ealstm/assets

# %%
#load the model
best_model = load_model("models/best_ealstm/")

# %%
best_weight # T-6, T-5, ... T-1, T
# Out:
# [0.05, 0.44, 0.89, 0.87, 0.84, 0.49, 0.29]

# %%
#saving best weight
with open('models/best_weight.json', 'w') as f:
    json.dump(best_weight, f)

# %%
#loading best weight
with open('models/best_weight.json', 'r') as f:
    best_weight = json.load(f)
